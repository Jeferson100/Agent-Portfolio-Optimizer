# %%
import json

# %%
with open("carteira_resultado.json", "r") as f:
    carteira_resultado = json.load(f)

# %%
with open("../data/carteira_resultado.json", "w") as f:
    json.dump(carteira_resultado, f)
